# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
df = pd.read_csv('breastcancerdf.csv')
df
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

# %%
x = df.iloc[:, :-2]
y = df['Class']

# %%
x
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 564    0
# 565    0
# 566    0
# 567    0
# 568    1
# Name: Class, Length: 569, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42, stratify = y)

# %%
scaler = StandardScaler()

# %%
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
x_train
# Out:
# array([[-1.07200079, -0.6584246 , -1.0880801 , ..., -1.07899452,
#         -1.35052668, -0.35265805],
#        [ 1.74874285,  0.06650173,  1.75115682, ...,  1.17859444,
#          1.54991557,  0.19107787],
#        [-0.97473376, -0.93112416, -0.99770871, ..., -1.28224057,
#         -1.70744192, -0.307734  ],
#        ...,
#        [ 0.39844772,  1.06867262,  0.50751384, ...,  1.45815049,
#          1.53492543,  0.16164487],
#        [ 0.85331409, -0.0380331 ,  0.9054796 , ...,  1.04414791,
#          2.10455077,  0.31035897],
#        [-0.91179628, -0.82431683, -0.87666079, ...,  0.27780272,
#         -0.51332734, -0.50756857]])

# %%
x_test
# Out:
# array([[ 1.56851278,  2.16401585,  1.74286587, ...,  0.68856004,
#          1.20214432, -0.14043064],
#        [-0.84027641, -0.5970672 , -0.8741735 , ..., -1.06990779,
#         -1.10124064, -0.81429139],
#        [-0.07072262,  1.19138742,  0.03202768, ...,  0.28522046,
#          0.57255843,  1.14997397],
#        ...,
#        [ 0.3583966 , -0.44935493,  0.48264098, ...,  0.77108239,
#          1.63386036,  0.54117564],
#        [-0.41401799,  1.07321761, -0.42314565, ...,  0.53093308,
#          0.06139464, -0.1280378 ],
#        [-0.6829327 , -0.69932953, -0.66607058, ..., -0.5914636 ,
#         -0.23615965, -0.16211811]])

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix

# %%
lr = LogisticRegression()
lr.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_predict = lr.predict(x_test)
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98        42
#            1       0.99      0.99      0.99        72
#
#     accuracy                           0.98       114
#    macro avg       0.98      0.98      0.98       114
# weighted avg       0.98      0.98      0.98       114

# %%
from sklearn.metrics import accuracy_score

print(f"Model Accuracy: {accuracy_score(y_test, y_predict) * 100:.3f} %")
# Out:
# Model Accuracy: 98.246 %

# %% [markdown]
# # ==========================================================

# %% [markdown]
# **testing model on unstandardized data, i.e: orignal data**

# %%
x1_train, x1_test, y1_train, y1_test = train_test_split(x, y, test_size = 0.2, random_state = 42, stratify = y)

# %%
lr.fit(x1_train, y1_train)
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y1_predict = lr.predict(x1_test)

# %%
print(classification_report(y1_test, y1_predict))
print(confusion_matrix(y1_test, y1_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.93      0.95        42
#            1       0.96      0.99      0.97        72
#
#     accuracy                           0.96       114
#    macro avg       0.97      0.96      0.96       114
# weighted avg       0.97      0.96      0.96       114
#
# [[39  3]
#  [ 1 71]]

# %%
print(f"Model Accuracy: {accuracy_score(y1_test, y1_predict) * 100:.3f} %")
# Out:
# Model Accuracy: 96.491 %

# %% [markdown]
# **so without balancing data through standardscaler, accuracy is 96.5% and with standardscalar accuracy is 98.246**

# %% [markdown]
# # ========================================================

# %%
print(classification_report(y_test, y_predict))
print(confusion_matrix(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98        42
#            1       0.99      0.99      0.99        72
#
#     accuracy                           0.98       114
#    macro avg       0.98      0.98      0.98       114
# weighted avg       0.98      0.98      0.98       114
#
# [[41  1]
#  [ 1 71]]

# %%
svm = SVC()
svm.fit(x_train, y_train)
y2_predict = svm.predict(x_test)

print(classification_report(y_test, y2_predict))
print(confusion_matrix(y_test, y2_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98        42
#            1       0.99      0.99      0.99        72
#
#     accuracy                           0.98       114
#    macro avg       0.98      0.98      0.98       114
# weighted avg       0.98      0.98      0.98       114
#
# [[41  1]
#  [ 1 71]]
